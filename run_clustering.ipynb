# %%
import pandas as pd
import numpy as np
import os
import umap
import hdbscan
import pickle

cwd = os.getcwd()
data_path = os.path.join(cwd,'data')
env_path = os.path.join(cwd,'.env')
models_path = os.path.join(cwd,'models')
# Out:
# WARNING:tensorflow:From C:\Users\eduar\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv(os.path.join(models_path,'bad_reviews_llama_topics.csv'))
df
# Out:
#                                                   text  cluster
# 0    Despite beating the game and collecting all 6 ...       83
# 1                  Everytime i die, i suck my own cock       37
# 2    I've played and beaten all the Dark Souls game...      116
# 3    They force 16:9, but still render at ultra wid...       66
# 4    BE CAREFUL WHEN BUYING THIS GAME\n\nFirst off,...       -1
# ..                                                 ...      ...
# 995  Mechanics, controls, menus, game design are al...       -1
# 996  Game broke my computer. Now my mic isn't being...       -1
# 997  its decent but a lot of broken multiplayer fea...       88
# 998  No ultrawide support.   I know this is a niche...       58
# 999  I hate that I love this game. Multiplayer is s...      119
#
# [1000 rows x 2 columns]
